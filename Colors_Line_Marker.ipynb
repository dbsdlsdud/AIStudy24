# %% [markdown]
# <a href="https://colab.research.google.com/github/dbsdlsdud/AIStudy24/blob/master/Colors_Line_Marker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 컬러 종류와 라인 종류

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 마커 종류

# %% [markdown]
# ![image.png](data:image/png;base64,...)
